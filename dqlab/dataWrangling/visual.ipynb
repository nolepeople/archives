# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = pd.read_csv("dataset/pgh.csv")
x = dataset["NAMA KELURAHAN"]
y = dataset["LAKI-LAKI WNI"]
plt.bar(x=np.arange(len(x)),height=y)
plt.xticks(np.arange(len(x)),x,rotation=30)
plt.show()
